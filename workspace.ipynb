# %%
from Supersymmetry_BPS_3pt import*
# Out:
# True

# %%
R[2]
# Out:
# addSUSY([
# SUSY((101.95835747992385-152.4826558489941j),['102', '202', '212']),
# SUSY((7.023658012883047+101.78949834081592j),['102', '112', '202']),
# SUSY((134.17021276595744-21.106382978723403j),['112', '202', '212']),
# SUSY((-64.2872340425532+71.22340425531912j),['102', '112', '212'])
# ])

# %%
QA1[2]
# Out:
# Operator(
# multi=addSUSY([
# SUSY((-1.7969695975290025-4.556056684305164j),['02'])
# ]),
# diff=addDiff([
# Diff((1.2388125769953193+11.324849576776296j),'111'),
# Diff((3.3591080061259895-3.005883754611893j),'101'),
# Diff((4.334424115025088-0.37888206549915704j),'211'),
# Diff((3.704683333166465-5.0597046141806405j),'201'),
# ]))

# %%
QA1[2].operate(R[2])
# Out:
# addSUSY([
# SUSY((-877.9356920268306-190.52135940606217j),['02', '102', '202', '212']),
# SUSY((451.13742439515204-214.9128179040444j),['02', '102', '112', '202']),
# SUSY((-337.2616704861407-573.3595661804169j),['02', '112', '202', '212']),
# SUSY((440.0200721201152+164.90999029573874j),['02', '102', '112', '212'])
# ])
